# %%
notebooks = [
    './CRM_Silver/Silver_cust_info',
    './CRM_Silver/Silver_prd_info',
    './CRM_Silver/Silver_sales_details',
    './ERP_Silver/Silver_cust_az12',
    './ERP_Silver/Silver_loc_a101',
    './ERP_Silver/Silver_px_cat_g1v2'
]


for notebook in notebooks:
    print(f"Running {notebook}")
    dbutils.notebook.run(notebook, timeout_seconds=0)
