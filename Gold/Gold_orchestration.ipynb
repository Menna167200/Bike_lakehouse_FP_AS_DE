# %%
notebooks = [
    './Gold_customers',
    './Gold_products',
    './Gold_sales_facts'
]

for notebook in notebooks:
    print(f"Running {notebook}")
    dbutils.notebook.run(notebook, timeout_seconds=0)
